# %%
from scipy import fftpack
from scipy.misc import electrocardiogram

# %% [markdown]
# ## Creación del dataset

# %%
import numpy as np
import matplotlib.pyplot as plt


ecg = electrocardiogram()

fs = 360
ts = 1/fs

time = np.arange(ecg.size)*ts
# Out:
# C:\Users\MOISES\AppData\Local\Temp\ipykernel_19888\3993141684.py:5: DeprecationWarning: scipy.misc.electrocardiogram has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.electrocardiogram instead.
#   ecg = electrocardiogram()

# %%
plt.plot(time, ecg)
plt.xlabel("Tiempo (s)")
plt.ylabel("Voltage (mV)")
# Out:
# Text(0, 0.5, 'Voltage (mV)')

# %%
X = fft(ecg)
sr = 360
N = len(X)
n = np.arange(N)
T = N/sr
freq = n/T 


plt.stem(freq, np.abs(X), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.xlim(0, 100)
# Out:
# (0.0, 100.0)

# %%
from scipy.fft import rfft, rfftfreq

X = rfft(ecg)
freq = rfftfreq(ecg.size, ts)

plt.plot(freq, np.abs(X))
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
sig_fft = fftpack.fft(ecg)
freqs = fftpack.fftfreq(ecg.size, d=ts)

# %%
plt.plot(freqs, np.abs(sig_fft))

# %% [markdown]
# ## Ejemplo2

# %%
# sampling rate
sr = 2000
# sampling interval
ts = 1.0/sr
t = np.arange(0,1,ts)

freq = 1.
x = 3*np.sin(2*np.pi*freq*t)

freq = 4
x += np.sin(2*np.pi*freq*t)

freq = 7   
x += 0.5* np.sin(2*np.pi*freq*t)

plt.figure(figsize = (8, 6))
plt.plot(t, x, 'r')
plt.ylabel('Amplitude')

plt.show()

# %%
from numpy.fft import fft, ifft

X = fft(x)
N = len(X)
n = np.arange(N)
T = N/sr
freq = n/T 

plt.figure(figsize = (12, 6))
plt.subplot(121)

plt.stem(freq, np.abs(X), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.xlim(0, 10)

plt.subplot(122)
plt.plot(t, ifft(X), 'r')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()

# %%
from scipy.fftpack import fft, ifft

X = fft(x)

plt.figure(figsize = (12, 6))
plt.subplot(121)

plt.stem(freq, np.abs(X), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.xlim(0, 10)

plt.subplot(122)
plt.plot(t, ifft(X), 'r')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()
